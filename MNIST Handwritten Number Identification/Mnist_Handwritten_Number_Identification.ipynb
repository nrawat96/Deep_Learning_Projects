# %% [markdown]
# # MNIST Dataset

# %% [markdown]
# The MNIST dataset is a built-in dataset provided by Keras. It consists of 70,000 28x28 grayscale images, each of which displays a single handwritten digit from 0 to 9. The training set consists of 60,000 images, while the test set has 10,000 images. Objective of model is to identify handwritten numbers.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow
from tensorflow import keras
from keras.layers import *
from keras.models import Sequential

# %%
from keras.datasets import mnist

# %%
(x_train, y_train),(x_test, y_test) = mnist.load_data()
print(x_train.shape, y_train.shape), print(x_test.shape, y_test.shape)
# Out:
# ...
# 11490434/11490434 [==============================] - 2s 0us/step
# (60000, 28, 28) (60000,)
# (10000, 28, 28) (10000,)
# (None, None)

# %%
x_train = x_train.reshape(x_train.shape[0], 28,28,1)
x_test = x_test.reshape(x_test.shape[0],28,28,1)
input_shape=(28,28,1)

# %%
print(x_train.shape, y_train.shape)
print(x_test.shape, y_test.shape)
# Out:
# (60000, 28, 28, 1) (60000,)
# (10000, 28, 28, 1) (10000,)

# %%
#normalization
x_train = x_train/255.0
x_test = x_test/255.0

# %%
y_train.dtype
# Out:
# dtype('uint8')

# %%
y_train = keras.utils.to_categorical(y_train)
y_test = keras.utils.to_categorical(y_test)

# %%
y_train.dtype
# Out:
# dtype('float32')

# %%
from keras.callbacks import EarlyStopping

# %% [markdown]
# ##Building Model

# %%
dnn = Sequential()
dnn.add(Flatten())
dnn.add(Dense(256, input_dim=2, activation='relu', input_shape=(28,28,1)))
dnn.add(Dropout(0.25))
dnn.add(Dense(256, activation='relu'))
dnn.add(Dropout(0.5))
dnn.add(Dense(10, activation='softmax'))
callback = EarlyStopping(monitor='val_loss', min_delta=0.001, patience=5, verbose=1, mode='auto')
dnn.compile(loss=keras.losses.categorical_crossentropy, optimizer='adam', metrics=['accuracy'])

# %%
history = dnn.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=20, callbacks=callback)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 7s 3ms/step - loss: 0.2909 - accuracy: 0.9122 - val_loss: 0.1108 - val_accuracy: 0.9666
# Epoch 2/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1432 - accuracy: 0.9575 - val_loss: 0.0863 - val_accuracy: 0.9725
# Epoch 3/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.1126 - accuracy: 0.9660 - val_loss: 0.0741 - val_accuracy: 0.9775
# Epoch 4/20
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.0976 - accuracy: 0.9708 - val_loss: 0.0820 - val_accuracy: 0.9751
# Epoch 5/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0845 - accuracy: 0.9739 - val_loss: 0.0772 - val_accuracy: 0.9762
# Epoch 6/20
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.0794 - accuracy: 0.9758 - val_loss: 0.0752 - val_accuracy: 0.9769
# Epoch 7/20
# ...
